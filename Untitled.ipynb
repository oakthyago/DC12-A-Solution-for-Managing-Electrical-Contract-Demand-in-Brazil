# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("dataframe.xlsx")

# %%
df.index
# Out:
# RangeIndex(start=0, stop=29864, step=1)

# %%
df.columns
# Out:
# Index(['F_MATRICULA', 'F_ANO', 'F_MES', 'F_KW_DTR', 'DC12', 'DC6'], dtype='object')

# %%
df.shape
# Out:
# (29864, 6)

# %%
df.head()
# Out:
#              F_ANO  F_MES  F_KW_DTR  DC12  DC6
# F_MATRICULA
# 63458         2003      1     65.19   NaN  NaN
# 63458         2003      2     80.77   NaN  NaN
# 63458         2003      3     64.37   NaN  NaN
# 63458         2003      4     64.78   NaN  NaN
# 63458         2003      5     65.19   NaN  NaN

# %%
df.set_index(['F_MATRICULA'],inplace=True)

# %%
df.sort_index(inplace=True)

# %%
df.loc[(slice(None)),['F_ANO','DC12']]
# Out:
#              F_ANO   DC12
# F_MATRICULA
# 63458         2003    NaN
# 63458         2003    NaN
# 63458         2003    NaN
# 63458         2003    NaN
# 63458         2003    NaN
# 63458         2003    NaN
# 63458         2003    NaN
# 63458         2003    NaN
# 63458         2003    NaN
# 63458         2003    NaN
# 63458         2003    NaN
# 63458         2003  125.0
# 63458         2004  125.0
# 63458         2004  128.0
# 63458         2004  128.0
# 63458         2004  128.0
# 63458         2004  128.0
# 63458         2004  128.0
# 63458         2004  127.0
# 63458         2004  125.0
# 63458         2004  125.0
# 63458         2004  125.0
# 63458         2004  125.0
# 63458         2004  125.0
# 63458         2005  125.0
# 63458         2005  124.0
# 63458         2005  125.0
# 63458         2005  125.0
# 63458         2005  125.0
# 63458         2005  125.0
# ...            ...    ...
# 9998248       2016   30.0
# 9998248       2017   30.0
# 9998248       2017   30.0
# ...

# %%
df
# Out:
#              F_ANO  F_MES  F_KW_DTR  DC12    DC6
# F_MATRICULA
# 63458            0      1     65.19     0    NaN
# 63458            0      2     80.77     0    NaN
# 63458            0      3     64.37     0    NaN
# 63458            0      4     64.78     0    NaN
# 63458            0      5     65.19     0    NaN
# 63458            0      6    130.38     0   80.0
# 63458            0      7    128.74     0  128.0
# 63458            0      8    127.92     0  128.0
# 63458            0      9    125.46     0  128.0
# 63458            0     10    120.54     0  128.0
# 63458            0     11    120.54     0  128.0
# 63458            0     12    118.08     0  128.0
# 63458            0      1    113.80     0  125.0
# 63458            0      2    139.58     0  125.0
# 63458            0      3    121.36     0  121.0
# 63458            0      4    124.64     0  124.0
# 63458            0      5    123.00     0  124.0
# 63458            0      6    139.40     0  139.0
# ...

# %%
df.reset_index(inplace=True)

# %%
df.to_excel("Teste2.xlsx")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-23e4d1b95160> in <module>
# ----> 1 df.to_excel("Teste2.xlsx")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2125         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    2126                         startcol=startcol, freeze_panes=freeze_panes,
# -> 2127                         engine=engine)
#    2128
#    2129     def to_json(self, path_or_buf=None, orient=None, date_format=None,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
# ...

# %%
df.set_index(['F_MATRICULA','F_ANO','F_MES'],inplace=True)

# %%
df.sort_index(inplace=True)

# %%
booleans =[]
n=0
last=0
for length in df.F_MATRICULA:
    if length != last:
        for a in range(12):
            booleans.append(True)
        last = length
    else:
        booleans.append(False)

# %%
len(booleans)
# Out:
# 31954

# %%
is_long = pd.Series(booleans)

# %%
df2=df[is_long]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df.loc[is_long,'DC12'] = 0

# %%
df.to_excel("Buceta.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-0b99ca3e2739> in <module>
# ----> 1 df.to_excel("Buceta.xlsx")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2125         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    2126                         startcol=startcol, freeze_panes=freeze_panes,
# -> 2127                         engine=engine)
#    2128
#    2129     def to_json(self, path_or_buf=None, orient=None, date_format=None,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
# ...

# %%
#df.loc[(slice(None),2003,[1,2,3,4,5,6]),'DC6']

# %%
df[is_long].loc[:,'DC12']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11       125.0
# 209       87.0
# 210       87.0
# 211       87.0
# 212       87.0
# 213       87.0
# 214       86.0
# 215       86.0
# 216       85.0
# 217       84.0
# 218       84.0
# 219       84.0
# 220       84.0
# 418       30.0
# 419       30.0
# 420       30.0
# 421       30.0
# 422       30.0
# 423       30.0
#          ...
# 29245    128.0
# 29246    130.0
# 29247    135.0
# 29248    136.0
# 29249    140.0
# 29250    140.0
# 29448     92.0
# 29449     92.0
# 29450     92.0
# 29451     91.0
# 29452     91.0
# 29453     91.0
# 29454     91.0
# 29455     91.0
# 29456     91.0
# 29457     91.0
# ...

# %%
# Out:
# 0

# %%
   # df.loc[(slice(None),2003),df['F_MES']]
